# %% [markdown]
# <a href="https://colab.research.google.com/github/drmamckinney/Week2-GitHub-MarkMcKinney/blob/main/Week2_Github_Mark_McKinney.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, GitHub from Colab")
# Out:
# Hello, GitHub from Colab
