# %% [markdown]
# <a href="https://colab.research.google.com/github/drmamckinney/Week2-GitHub-MarkMcKinney/blob/main/Week3_Python_Libraries_Mark_McKinney.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab M0.3 – Working with Python Libraries
#
# Mark McKinney
#
# This notebook demonstrates importing common Python libraries, loading a dataset with pandas, generating summary statistics, and checking for missing values.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import tensorflow as tf

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
df = pd.read_csv(
    "https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv"
)

df.head()
# Out:
#    Index   Height(Inches)"   "Weight(Pounds)"
# 0      1             65.78             112.99
# 1      2             71.52             136.49
# 2      3             69.40             153.03
# 3      4             68.22             142.34
# 4      5             67.79             144.30

# %%
df.describe()
# Out:
#             Index   Height(Inches)"   "Weight(Pounds)"
# count  200.000000        200.000000         200.000000
# mean   100.500000         67.949800         127.221950
# std     57.879185          1.940363          11.960959
# min      1.000000         63.430000          97.900000
# 25%     50.750000         66.522500         119.895000
# 50%    100.500000         67.935000         127.875000
# 75%    150.250000         69.202500         136.097500
# max    200.000000         73.900000         158.960000

# %%
df.isnull().sum()
# Out:
# Index                0
#  Height(Inches)"     0
#  "Weight(Pounds)"    0
# dtype: int64
